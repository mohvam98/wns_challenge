# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv("train.csv")

# %%
train.head(5)
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click
# 0           old      0         0
# 1        latest      1         1
# 2  intermediate      1         0
# 3        latest      1         0
# 4        latest      0         0

# %%
item=pd.read_csv("item_data.csv")

# %%
item.head(5)
# Out:
#    item_id  item_price  category_1  category_2  category_3  product_type
# 0    26880        4602          11          35          20          3040
# 1    54939        3513          12          57          85          6822
# 2    40383         825          17           8         279          1619
# 3     8777        2355          13          58         189          5264
# 4   113705        1267          17          39         151         10239

# %%
view=pd.read_csv("view_log.csv")

# %%
view.head(5)
# Out:
#            server_time device_type  session_id  user_id  item_id
# 0  2018-10-15 08:58:00     android      112333     4557    32970
# 1  2018-10-15 08:58:00     android      503590    74788     7640
# 2  2018-10-15 08:58:00     android      573960    23628   128855
# 3  2018-10-15 08:58:00     android      121691     2430    12774
# 4  2018-10-15 08:58:00     android      218564    19227    28296

# %%
test=pd.read_csv("test.csv")

# %%
test.head(5)
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  a9e7126a585a69a32bc7414e9d0c0ada  2018-12-13 07:44:00    44754       127
# 1  caac14a5bf2ba283db7708bb34855760  2018-12-13 07:45:00    29656        44
# 2  13f10ba306a19ce7bec2f3cae507b698  2018-12-13 07:46:00    25234       296
# 3  39c4b4dc0e9701b55a0a4f072008fb3f  2018-12-13 07:47:00    22988       207
# 4  bf5a572cca75f5fc67f4b14e58b11d70  2018-12-13 07:48:00    35431       242
#
#   os_version  is_4G
# 0     latest      1
# 1     latest      0
# 2     latest      1
# 3     latest      1
# 4     latest      1

# %%
sub=pd.read_csv("sample_submission.csv")

# %%
sub.head(5)
# Out:
#                       impression_id  is_click
# 0  a9e7126a585a69a32bc7414e9d0c0ada         0
# 1  caac14a5bf2ba283db7708bb34855760         0
# 2  13f10ba306a19ce7bec2f3cae507b698         0
# 3  39c4b4dc0e9701b55a0a4f072008fb3f         0
# 4  bf5a572cca75f5fc67f4b14e58b11d70         0

# %%
test.shape
# Out:
# (90675, 6)

# %%
sub.shape
# Out:
# (90675, 2)

# %%
item.size
# Out:
# 796566

# %%
view.size
# Out:
# 15593110

# %%
vi.size
# Out:
# 31168400

# %%
vi=pd.merge(item,view,how='inner')

# %%
vi.head(5)
# Out:
#    item_id  item_price  category_1  category_2  category_3  product_type  \
# 0    26880        4602          11          35          20          3040
# 1    26880        4602          11          35          20          3040
# 2    54939        3513          12          57          85          6822
# 3    54939        3513          12          57          85          6822
# 4    54939        3513          12          57          85          6822
#
#            server_time device_type  session_id  user_id
# 0  2018-10-24 15:22:00     android      884484    24873
# 1  2018-10-24 15:30:00     android      884484    24873
# 2  2018-10-19 09:31:00     android      417118    34832
# 3  2018-10-21 03:08:00     android      408682    59619
# 4  2018-10-21 13:31:00     android      934901    52345

# %%
t1=pd.merge(train,vi,how='inner')

# %%
t1.head(5)
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  621bf66ddb7c962aa0d22ac97d69b793  2018-11-15 00:19:00    87862       422
# 2  ab394288aed46588bdc90bf4b541ec0d  2018-11-16 17:29:00    87862       422
# 3  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 4  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
#
#   os_version  is_4G  is_click  item_id  item_price  category_1  category_2  \
# 0        old      0         0    43886        2350          11          35
# 1        old      0         0    43886        2350          11          35
# 2        old      0         0    43886        2350          11          35
# 3     latest      1         1   109074        6330          10          63
# 4     latest      1         1   109074        6330          10          63
#
# ...

# %%
t2=pd.merge(test,vi,how='inner')

# %%
t2.head(5)
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  a9e7126a585a69a32bc7414e9d0c0ada  2018-12-13 07:44:00    44754       127
# 1  30e58abb328b85fd43398973f4daa190  2018-12-14 00:02:00    44754       127
# 2  9d43b6d8bc2e0cf1e0e67c0257f26497  2018-12-12 17:51:00    44754       127
# 3  3a6d8d6593becf63832bfc876768800f  2018-12-12 21:30:00    44754       127
# 4  0bef27d1e4eaac44e404f285dce6000b  2018-12-15 19:25:00    44754       127
#
#   os_version  is_4G  item_id  item_price  category_1  category_2  category_3  \
# 0     latest      1   128995       23424           1          42         220
# 1     latest      0   128995       23424           1          42         220
# 2     latest      1   128995       23424           1          42         220
# 3     latest      1   128995       23424           1          42         220
# 4     latest      1   128995       23424           1          42         220
#
# ...

# %%
t2.shape
# Out:
# (3869280, 15)

# %%
t1.shape
# Out:
# (11046039, 16)

# %%
print(t2.isnull().sum())
# Out:
# impression_id      0
# impression_time    0
# user_id            0
# app_code           0
# os_version         0
# is_4G              0
# item_id            0
# item_price         0
# category_1         0
# category_2         0
# category_3         0
# product_type       0
# server_time        0
# device_type        0
# session_id         0
# dtype: int64

# %%
print(t2["item_id"].value_counts())
# Out:
# 425       17277
# 118262    15060
# 33633     14879
# 72955     14308
# 64835     12874
# 127900    12483
# 84704     11111
# 119516    11037
# 104035    10835
# 79527     10706
# 76404      9949
# 89373      9538
# 95249      9514
# 30048      9324
# 44686      9232
# 54546      9181
# 71406      9124
# 68968      8898
# 45690      8879
# 3500       8850
# 15757      8673
# 1528       8581
# 78603      8319
# 91322      8195
# 71978      8148
# 76156      8114
# 72120      8108
# 73972      8071
# 2121       7672
# 49461      7660
#           ...
# 114001        1
# 27519         1
# 65814         1
# 71957         1
# 124250        1
# 11127         1
# 119052        1
# 70206         1
# 72255         1
# 93514         1
# 103765        1
# 61955         1
# 18748         1
# 51716         1
# 86872         1
# 3430          1
# 1383          1
# 2356          1
# 42355         1
# 53767         1
# 64888         1
# 80725         1
# 49453         1
# 51500         1
# ...

# %%
t2.duplicated(subset=None, keep='first')
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 3869250    False
# 3869251     True
# 3869252    False
# 3869253    False
# 3869254     True
# 3869255    False
# 3869256    False
# 3869257    False
# 3869258    False
# 3869259    False
# 3869260    False
# 3869261    False
# 3869262    False
# 3869263    False
# 3869264    False
# 3869265    False
# 3869266    False
# 3869267    False
# 3869268    False
# 3869269    False
# 3869270    False
# ...

# %%
t1[t1'[['impression_id']].duplicated() == True]
# Out:
#                              impression_id      impression_time  user_id  \
# 4         45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 5         45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 6         45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 7         45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 8         45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 9         45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 10        45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 11        45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 12        45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 13        45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 14        45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410
# 16        6b18886bc278247582704943f5c66eb9  2018-11-16 16:31:00    63410
# ...

# %%
print(t1["app_code"].value_counts())
# Out:
# 207    1516916
# 386    1362893
# 190     763587
# 127     485459
# 129     445794
# 385     392594
# 296     384519
# 371     356905
# 3       312408
# 283     258320
# 469     258241
# 5       245878
# 249     239883
# 244     232091
# 44      223896
# 32      219137
# 145     195041
# 242     149235
# 213     134600
# 202     112252
# 463     102256
# 465      98116
# 163      94709
# 473      94086
# 231      84715
# 359      83442
# 151      80645
# 318      72521
# 508      70918
# 38       70011
#         ...
# 141          6
# 91           6
# 358          6
# 12           6
# 238          5
# 363          5
# 313          5
# 73           5
# 208          4
# 341          4
# 270          4
# 212          4
# 172          4
# 479          4
# 404          4
# 90           4
# 52           3
# 70           3
# 417          3
# 476          2
# 179          2
# 345          2
# 34           2
# 419          2
# 72           2
# 429          2
# 113          2
# 205          2
# ...
